# %%
import pandas as pd

# %%
# ->Filteration
# data={"name":,"age":,"city":}
# 1.show people from delhi
# 2.show people with age b/w 25 and 30
# 3.sort data by age desc    sort_value
# 4.find youngest person df.loc[df["age"].idxmin()]
# 5.find oldest person
# from tips dataset
# filter rows by smoker=no and total_bill>=10
data={"name":["shalini","nidhi","raman","atul"],
     "age":[23,45,78,12],
     "city":["delhi","chd","chd","delhi"]
     }
df=pd.DataFrame(data)
df
# Out:
#       name  age   city
# 0  shalini   23  delhi
# 1    nidhi   45    chd
# 2    raman   78    chd
# 3     atul   12  delhi

# %%
df[df["city"]=="delhi"]
# Out:
#       name  age   city
# 0  shalini   23  delhi
# 3     atul   12  delhi

# %%
df[(df["age"]>20) & (df["age"]<30)]
# Out:
#       name  age   city
# 0  shalini   23  delhi

# %%
df.sort_values(by="age",ascending=False)
# Out:
#       name  age   city
# 2    raman   78    chd
# 1    nidhi   45    chd
# 0  shalini   23  delhi
# 3     atul   12  delhi

# %%
df.loc[[df["age"].idxmax()]]
# Out:
#     name  age city
# 2  raman   78  chd

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
tips=sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
dt=tips[(tips["day"]=="Sun") & 
     (tips["time"]=="Dinner") & (tips["sex"]=="Male")]
dt
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 1         10.34  1.66  Male     No  Sun  Dinner     3
# 2         21.01  3.50  Male     No  Sun  Dinner     3
# 3         23.68  3.31  Male     No  Sun  Dinner     2
# 5         25.29  4.71  Male     No  Sun  Dinner     4
# 6          8.77  2.00  Male     No  Sun  Dinner     2
# 7         26.88  3.12  Male     No  Sun  Dinner     4
# 8         15.04  1.96  Male     No  Sun  Dinner     2
# 9         14.78  3.23  Male     No  Sun  Dinner     2
# 10        10.27  1.71  Male     No  Sun  Dinner     2
# 12        15.42  1.57  Male     No  Sun  Dinner     2
# 13        18.43  3.00  Male     No  Sun  Dinner     4
# 15        21.58  3.92  Male     No  Sun  Dinner     2
# 17        16.29  3.71  Male     No  Sun  Dinner     3
# 41        17.46  2.54  Male     No  Sun  Dinner     2
# 42        13.94  3.06  Male     No  Sun  Dinner     2
# 43         9.68  1.32  Male     No  Sun  Dinner     2
# ...

# %%
# ->Data Cleaning
# same dataframe with None in age and city
# 1.df.isnull()
# 2.df.dropna()
# 3.fill missing age with avg age
# 4.fill city with unknown
data={"name":["shalini","nidhi","raman","atul"],
     "age":[None,45,78,12],
     "city":["delhi","chd",None,"delhi"]
     }
df=pd.DataFrame(data)
df
# Out:
#       name   age   city
# 0  shalini   NaN  delhi
# 1    nidhi  45.0    chd
# 2    raman  78.0   None
# 3     atul  12.0  delhi

# %%
df.dropna()
# Out:
#     name   age   city
# 1  nidhi  45.0    chd
# 3   atul  12.0  delhi

# %%
df["age"]=df["age"].fillna(df["age"].mean())
df["city"]=df["city"].fillna("Unknown")
df
# Out:
#       name   age     city
# 0  shalini  45.0    delhi
# 1    nidhi  45.0      chd
# 2    raman  78.0  Unknown
# 3     atul  12.0    delhi

# %%
# ->Grouping
# data={"desg":,"dept":,"salary":} (split->apply->combine)
# 1.avg salary by dept      df.groupby("dept")["salary"].mean()
# 2.max salary by dept      df.groupby("dept")["salary"].max()
# 3.count employees per dept    df.groupby("dept").size()
# 4.multiple agg   .agg(["mean","max","min"])
# 5.diff agg per col  df.groupby("dept").agg({"salary":["mean","max"],"desg":"count"})
# 6.grouping on multiple cols 
# 7.iterating on group for name,group in df.groupby("dept")
# 8.filtering groups  df.groupby("dept").filter(lambda x:x["salary"].mean()>50000)
# 9.named agg df.groupby("dept").agg(avg_salary=("salary","mean"),max_salary=("salary","max"))
# 10.grouping with cond   df.groupby(df["salary"]>60000)["salary"].mean()
# 11.ranking within group df["rank_in_grp]=df.groupby("dept")["salary"].rank(ascending=False)   
# df[df["rank_in_grp"]<=2]
# 12.which dept has highest avg.salary   df.groupby("dept")["salary"].mean().idxmax()
# gapminder
# 1.groupby year avg lifeExp  .mean()   .agg(np.mean)
# 2.df.groupby(["year","continent"])[["lifeexp","gdppercap"]].agg(np.mean)
# reset_index()
# 3.avg total_bill for each value of smoker,day and time

# %%
data={"dept":["it","sales","it","marketing","hr","sales","sales"],
       "salary":[20000,25000,40000,27000,12000,25678,34000],
      "desg":["a","b","b","aa","a","b","aa"]
     }
df=pd.DataFrame(data)
df
# Out:
#         dept  salary desg
# 0         it   20000    a
# 1      sales   25000    b
# 2         it   40000    b
# 3  marketing   27000   aa
# 4         hr   12000    a
# 5      sales   25678    b
# 6      sales   34000   aa

# %%
df.groupby("dept")["salary"].mean()
# Out:
# dept
# hr           12000.0
# it           30000.0
# marketing    27000.0
# sales        28226.0
# Name: salary, dtype: float64

# %%
df.groupby("dept").agg({"salary":[min,max,"mean"]})
# Out:
#           salary
#              min    max     mean
# dept
# hr         12000  12000  12000.0
# it         20000  40000  30000.0
# marketing  27000  27000  27000.0
# sales      25000  34000  28226.0

# %%
gap=pd.read_csv("gapminder.tsv",delimiter="\t")
gap.head(10)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106
# 5  Afghanistan      Asia  1977   38.438  14880372  786.113360
# 6  Afghanistan      Asia  1982   39.854  12881816  978.011439
# 7  Afghanistan      Asia  1987   40.822  13867957  852.395945
# 8  Afghanistan      Asia  1992   41.674  16317921  649.341395
# 9  Afghanistan      Asia  1997   41.763  22227415  635.341351

# %%
gap.groupby("continent").agg({"lifeExp":"mean","pop":sum})
# Out:
#              lifeExp          pop
# continent
# Africa     48.865330   6187585961
# Americas   64.658737   7351438499
# Asia       60.064903  30507333901
# Europe     71.903686   6181115304
# Oceania    74.326208    212992136

# %%
gap.groupby(["continent","country"])["lifeExp"].mean().reset_index()
# Out:
#     continent         country    lifeExp
# 0      Africa         Algeria  59.030167
# 1      Africa          Angola  37.883500
# 2      Africa           Benin  48.779917
# 3      Africa        Botswana  54.597500
# 4      Africa    Burkina Faso  44.694000
# ..        ...             ...        ...
# 137    Europe     Switzerland  75.565083
# 138    Europe          Turkey  59.696417
# 139    Europe  United Kingdom  73.922583
# 140   Oceania       Australia  74.662917
# 141   Oceania     New Zealand  73.989500
#
# [142 rows x 3 columns]

# %%
gap.groupby("continent").size()
# Out:
# continent
# Africa      624
# Americas    300
# Asia        396
# Europe      360
# Oceania      24
# dtype: int64

# %%
# continent------>country  rank based on lifeexp
# best 2 countries from each continent
df["rank"]=
# Out:
#         dept  salary desg
# 0         it   20000    a
# 1      sales   25000    b
# 2         it   40000    b
# 3  marketing   27000   aa
# 4         hr   12000    a
# 5      sales   25678    b
# 6      sales   34000   aa

# %%
df["rank"]=df.groupby("dept")["salary"].rank(ascending=False)
df[df["rank"]<=2]
# Out:
#         dept  salary desg  rank
# 0         it   20000    a   2.0
# 2         it   40000    b   1.0
# 3  marketing   27000   aa   1.0
# 4         hr   12000    a   1.0
# 5      sales   25678    b   2.0
# 6      sales   34000   aa   1.0

# %%
gap["rank"]=gap.groupby(["continent","country"])["lifeExp"].rank(ascending=False)
gap[gap["rank"]<=2]
# Out:
#           country continent  year  lifeExp       pop    gdpPercap  rank
# 10    Afghanistan      Asia  2002   42.129  25268405   726.734055   2.0
# 11    Afghanistan      Asia  2007   43.828  31889923   974.580338   1.0
# 22        Albania    Europe  2002   75.651   3508512  4604.211737   2.0
# 23        Albania    Europe  2007   76.423   3600523  5937.029526   1.0
# 34        Algeria    Africa  2002   70.994  31287142  5288.040382   2.0
# ...           ...       ...   ...      ...       ...          ...   ...
# 1679  Yemen, Rep.      Asia  2007   62.698  22211743  2280.769906   1.0
# 1685       Zambia    Africa  1977   51.386   5216550  1588.688299   2.0
# 1686       Zambia    Africa  1982   51.821   6100407  1408.678565   1.0
# 1699     Zimbabwe    Africa  1987   62.351   9216418   706.157306   1.0
# 1700     Zimbabwe    Africa  1992   60.377  10704340   693.420786   2.0
#
# [284 rows x 7 columns]

# %%
# gap.groupby("continent").filter(lambda x:x["lifeExp"]>70)
# ["lifeExp"].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 gap.groupby("continent").filter(lambda x:x["lifeExp"]>70)
#       2 ["lifeExp"].mean()
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\groupby\generic.py:1395, in DataFrameGroupBy.filter(self, func, dropna, *args, **kwargs)
#    1392             indices.append(self._get_index(name))
#    1393     else:
#    1394         # non scalars aren't allowed
# -> 1395         raise TypeError(
#    1396             f"filter function returned a {type(res).__name__}, "
#    1397             "but expected a scalar bool"
#    1398         )
#    1400 return self._apply_filter(indices, dropna)
#
# TypeError: filter function returned a Series, but expected a scalar bool

# %%
df.groupby("dept").filter(lambda x:x["salary"].mean()>20000)
# Out:
#         dept  salary desg  rank
# 0         it   20000    a   2.0
# 1      sales   25000    b   3.0
# 2         it   40000    b   1.0
# 3  marketing   27000   aa   1.0
# 5      sales   25678    b   2.0
# 6      sales   34000   aa   1.0

# %%
gap.groupby("continent")["lifeExp"].mean()
# Out:
# continent
# Africa      48.865330
# Americas    64.658737
# Asia        60.064903
# Europe      71.903686
# Oceania     74.326208
# Name: lifeExp, dtype: float64

# %%
gap.groupby("continent").filter(lambda x:x["lifeExp"].mean()>70)
# Out:
#              country continent  year  lifeExp       pop     gdpPercap  rank
# 12           Albania    Europe  1952   55.230   1282697   1601.056136  12.0
# 13           Albania    Europe  1957   59.280   1476505   1942.284244  11.0
# 14           Albania    Europe  1962   64.820   1728137   2312.888958  10.0
# 15           Albania    Europe  1967   66.220   1984060   2760.196931   9.0
# 16           Albania    Europe  1972   67.690   2263554   3313.422188   8.0
# ...              ...       ...   ...      ...       ...           ...   ...
# 1603  United Kingdom    Europe  1987   75.007  56981620  21664.787670   5.0
# 1604  United Kingdom    Europe  1992   76.420  57866349  22705.092540   4.0
# 1605  United Kingdom    Europe  1997   77.218  58808266  26074.531360   3.0
# 1606  United Kingdom    Europe  2002   78.471  59912431  29478.999190   2.0
# 1607  United Kingdom    Europe  2007   79.425  60776238  33203.261280   1.0
#
# [384 rows x 7 columns]

# %%
1.group by country,year    mean pop
2.group by continent,country only records >1990
3.group by continent 2 most popul
