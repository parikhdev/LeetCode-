# %% [markdown]
# ### Implementing Stack using `collections`

# %%
from collections import deque

# %%
stack = deque()

# %%
stack
# Out:
# deque([])

# %%
len(stack)
# Out:
# 0

# %%
len(stack) == 0
# Out:
# True

# %%
print(stack)
# Out:
# deque([])

# %%
stack.append(20)

# %%
stack
# Out:
# deque([20])

# %%
stack.append(15)
stack.append(35)
stack.append(10)

# %%
stack
# Out:
# deque([20, 15, 35, 10])

# %%
stack.pop()
# Out:
# 10

# %%
stack
# Out:
# deque([20, 15, 35])

# %%
popped = stack.pop()

# %%
stack
# Out:
# deque([20, 15])

# %%
popped
# Out:
# 35

# %%
stack[-1]
# Out:
# 15
