# %% [markdown]
# ## Hashing Operations using Dictionary

# %%
student = {
    'name': 'John',
    'age': 18,
    'gender': 'male'
}

student
# Out:
# {'name': 'John', 'age': 18, 'gender': 'male'}

# %% [markdown]
# ### Insertion

# %%
student['nationality'] = 'Indian'
student
# Out:
# {'name': 'John', 'age': 18, 'gender': 'male', 'nationality': 'Indian'}

# %%
student.update({'age': 20})
student
# Out:
# {'name': 'John', 'age': 20, 'gender': 'male', 'nationality': 'Indian'}

# %%
student.update({'color': 'red'})
student
# Out:
# {'name': 'John',
#  'age': 20,
#  'gender': 'male',
#  'nationality': 'Indian',
#  'color': 'red'}

# %%
student.setdefault('religion', 'NA')

# %%
student
# Out:
# {'name': 'John',
#  'age': 20,
#  'gender': 'male',
#  'nationality': 'Indian',
#  'color': 'red',
#  'religion': None}

# %% [markdown]
# ### Searching

# %%
# student['country']

# %% [markdown]
# ### Update

# %%
student
# Out:
# {'name': 'John',
#  'age': 20,
#  'gender': 'male',
#  'nationality': 'Indian',
#  'color': 'red',
#  'religion': None}

# %%
student.update({'age': 21, 'state': 'Tamil Nadu'})
student
# Out:
# {'name': 'John',
#  'age': 21,
#  'gender': 'male',
#  'nationality': 'Indian',
#  'color': 'red',
#  'religion': None,
#  'state': 'Tamil Nadu'}

# %%
student['color'] = 'dark red'
student
# Out:
# {'name': 'John',
#  'age': 21,
#  'gender': 'male',
#  'nationality': 'Indian',
#  'color': 'dark red',
#  'religion': None,
#  'state': 'Tamil Nadu'}

# %% [markdown]
# ### Deletion

# %%
del student['religion']
student
# Out:
# {'name': 'John',
#  'age': 21,
#  'gender': 'male',
#  'nationality': 'Indian',
#  'color': 'dark red',
#  'state': 'Tamil Nadu'}

# %%
student.pop('state')
# Out:
# 'Tamil Nadu'

# %%
student
# Out:
# {'name': 'John',
#  'age': 21,
#  'gender': 'male',
#  'nationality': 'Indian',
#  'color': 'dark red'}

# %%
student.popitem()
# Out:
# ('color', 'dark red')

# %%
student
# Out:
# {'name': 'John', 'age': 21, 'gender': 'male', 'nationality': 'Indian'}

# %% [markdown]
# ### Membership

# %%
'name' in student
# Out:
# True

# %%
'fruit' in student
# Out:
# False

# %% [markdown]
# ### Iteration

# %%
student
# Out:
# {'name': 'John', 'age': 21, 'gender': 'male', 'nationality': 'Indian'}

# %%
for x in student:
    print(x)
# Out:
# name
# age
# gender
# nationality

# %%
for k in student:
    print(f'{k}: {student[k]}')
# Out:
# name: John
# age: 21
# gender: male
# nationality: Indian

# %%
for k, v in student.items():
    print(f'{k}: {v}')
# Out:
# name: John
# age: 21
# gender: male
# nationality: Indian
