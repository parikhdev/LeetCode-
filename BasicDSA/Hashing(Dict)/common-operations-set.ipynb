# %% [markdown]
# ## Hashing Operations using Sets

# %%
s = {'John', 21, 'country', 100, 22.5}
s
# Out:
# {100, 21, 22.5, 'John', 'country'}

# %% [markdown]
# ### Insertion

# %%
s.add('city')

# %%
s
# Out:
# {100, 21, 22.5, 'John', 'city', 'country'}

# %% [markdown]
# ### Searching / Membership

# %%
'John' in s
# Out:
# True

# %%
55 in s
# Out:
# False

# %% [markdown]
# ### Deletion

# %%
s
# Out:
# {100, 21, 22.5, 'John', 'city', 'country'}

# %%
s.pop()
s
# Out:
# {21, 22.5, 'John', 'city', 'country'}

# %%
s.pop()
s
# Out:
# {21, 22.5, 'John', 'country'}

# %%
s.remove('country')
s
# Out:
# {21, 22.5, 'John'}

# %% [markdown]
# ### Iteration

# %%
for x in s:
    print(x)
# Out:
# John
# 21
# 22.5
